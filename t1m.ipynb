# %% [markdown]
# # TAREA 1 EJERCICIOS PAGINA 8 Y 9

# %%
# !pip install --target=$nb_path nacal
from nacal import *
from IPython.display import display, Math, Latex
# Out:
# Collecting nacal
#   Downloading nacal-0.1.30-py3-none-any.whl (33 kB)
# Requirement already satisfied: sympy>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from nacal) (1.12)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy>=1.1.0->nacal) (1.3.0)
# Installing collected packages: nacal
# Successfully installed nacal-0.1.30

# %% [markdown]
# # 1.¿Es verdad que
# $$\begin{pmatrix}1\\2\\3\\\end{pmatrix}+\begin{pmatrix}4\\5\\6\\\end{pmatrix}=\begin{pmatrix}4\\5\\6\\\end{pmatrix}+\begin{pmatrix}1\\2\\3\\\end{pmatrix}$$
#
# ¿Es cierto solo para los números del ejemplo?o ¿es una regla general para cualquier par de vectores?

# %%
a = Vector( [1, 2, 3] )
b = Vector( [4, 5, 6] )
display(Latex(latex(a+b)))
print()
display(Latex(latex(b+a)))
# Out:
# \begin{pmatrix}5\\ 7\\ 9\end{pmatrix}
# \begin{pmatrix}5\\ 7\\ 9\end{pmatrix}

# %% [markdown]
# #2.¿Es verdad que
# $$\begin{pmatrix}1\\2\\\end{pmatrix}+\begin{pmatrix}\begin{pmatrix}4\\5\\\end{pmatrix}+\begin{pmatrix}1\\0\\\end{pmatrix}\end{pmatrix}
# =\begin{pmatrix}\begin{pmatrix}1\\2\\\end{pmatrix}+\begin{pmatrix}4\\5\\\end{pmatrix}\end{pmatrix}+\begin{pmatrix}1\\0\\\end{pmatrix}?$$
#
# El parentesis significa que primero hay que hacer la suma dentro del parentesis, y al vector resultante sumarle el vector de fuera.
#
# ¿Es cierto solo para los números del ejemplo? o ¿es una regla general para cualquier trio de vectores

# %%
a=Vector([1,2])
b=Vector([4,5])
c=Vector([1,0])

display(Latex(latex(a+(b+c))))
print()
display(Latex(latex((a+b)+c)))
# Out:
# \begin{pmatrix}6\\ 7\end{pmatrix}
# \begin{pmatrix}6\\ 7\end{pmatrix}

# %% [markdown]
# # 3.¿Es verdad que
#
# $$\begin{pmatrix}4 \\5\\6\end{pmatrix}+\begin{pmatrix}0\\0\\0\end{pmatrix}
# =\begin{pmatrix}4 \\5\\6\end{pmatrix}?$$
#
# ¿Es cierto solo para los vectores del ejemplo? o ¿es una regla general para cualquier par de vectores?

# %%
a=Vector([4,5,6])
b=Vector([0,0,0])
display(Latex(latex(a+b)))
# Out:
# \begin{pmatrix}4\\ 5\\ 6\end{pmatrix}

# %% [markdown]
# # 4.¿Es verdad que
#
# $$\begin{pmatrix}4 \\5\\6\end{pmatrix}+\begin{pmatrix}-4\\-5\\-6\end{pmatrix}=\begin{pmatrix}0 \\0\\0\end{pmatrix}?$$
#
# ¿Es cierto solo para los vectores del ejemplo? o ¿es una regla general para cualquier par de vectores?

# %%
a=Vector([4,5,6])
b=Vector([-4,-5,-6])
display(Latex(latex(a+b)))
# Out:
# \begin{pmatrix}0\\ 0\\ 0\end{pmatrix}

# %% [markdown]
# # 5.¿Es verdad que
# $$2\begin{pmatrix}\begin{pmatrix}1\\-1\\\end{pmatrix}+\begin{pmatrix}4\\5\\\end{pmatrix}\end{pmatrix}=2\begin{pmatrix}1\\-1\\\end{pmatrix}+2\begin{pmatrix}4\\5\\\end{pmatrix}?$$
# ¿Es una regla general para cualquier par de vectores? ¿Y si cambiamos el escalar 2 por otro número?

# %%
a=Vector([1,-1])
b=Vector([4,5])
display(Latex(latex(2*(a+b))))
print()
display(Latex(latex((2*a)+(2*b))))
# Out:
# \begin{pmatrix}10\\ 8\end{pmatrix}
# \begin{pmatrix}10\\ 8\end{pmatrix}

# %% [markdown]
# # 6.¿Es verdad que
# $$(2+3)\begin{pmatrix}1\\2\\3\\\end{pmatrix}=2\begin{pmatrix}1\\2\\3\\\end{pmatrix}+3\begin{pmatrix}1\\2\\3\\\end{pmatrix}?$$
#
# ¿Es una regla general para cualquier par de vectores? ¿y si cambiamos los escalares 2 y 3 por otros números?

# %%
a=Vector([1,2,3])
display(Latex(latex((2+3)*a)))
print()
display(Latex(latex((2*a)+(3*a))))
# Out:
# \begin{pmatrix}5\\ 10\\ 15\end{pmatrix}
# \begin{pmatrix}5\\ 10\\ 15\end{pmatrix}

# %% [markdown]
# # 7.¿Es verdad que
# $$2(3\begin{pmatrix}1\\2\\\end{pmatrix})=(2*3)\begin{pmatrix}1\\2\\\end{pmatrix}$$
#
# ¿Es una regla general para cualquier par de vectores? ¿y si cambiamos los escalares 2 y 3 por otros números?

# %%
a=Vector([1,2])
display(Latex(latex((2*(3*a)))))
print()
display(Latex(latex((2*3)*a)))
# Out:
# \begin{pmatrix}6\\ 12\end{pmatrix}
# \begin{pmatrix}6\\ 12\end{pmatrix}

# %% [markdown]
# # 8.¿Es verdad que si a=1
# $$a\begin{pmatrix}1\\2\\3\\\end{pmatrix}=\begin{pmatrix}1\\2\\3\\\end{pmatrix}?$$
# ¿Es cierto solo para el escalar a = 1?

# %%
a=1
b=Vector([1,2,3])
display(Latex(latex(a*b)))
# Out:
# \begin{pmatrix}1\\ 2\\ 3\end{pmatrix}
